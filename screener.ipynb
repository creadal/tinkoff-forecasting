# %%
import pandas as pd

df = pd.read_csv('nasdaq_screener_1653129008576.csv')
df.sample()
# Out:
#      Symbol                                        Name Last Sale  Net Change  \
# 4451  LBTYB  Liberty Global plc Class B Ordinary Shares  $22.5401         0.0
#
#      % Change    Market Cap         Country  IPO Year  Volume  \
# 4451    0.00%  1.137863e+10  United Kingdom       NaN       1
#
#                   Sector                               Industry
# 4451  Telecommunications  Cable & Other Pay Television Services

# %%
all_cap = df['Market Cap'].sum()
all_cap
# Out:
# 55150879673027.0

# %%
df['weight'] = df['Market Cap'] / all_cap

# %%
df.sample(10)
# Out:
#       Symbol                                               Name Last Sale  \
# 4831    MEDP                 Medpace Holdings Inc. Common Stock   $133.87
# 2533    EMKR                    EMCORE Corporation Common Stock     $3.11
# 6431    RF^E  Regions Financial Corporation Depositary Share...    $17.82
# 760      AUS  Austerlitz Acquisition Corporation I Class A O...    $9.761
# 3934  IIPR^A  Innovative Industrial Properties Inc. 9.00% Se...    $26.19
# 7497    TLYS                          Tilly's Inc. Common Stock     $8.07
# 2155     DDL  Dingdong (Cayman) Limited American Depositary ...     $4.41
# 1673    CLGN      CollPlant Biotechnologies Ltd Ordinary Shares     $9.95
# 2113   DATSW                      DatChat Inc. Series A Warrant     $0.36
# 5323     NLY         Annaly Capital Management Inc Common Stock     $6.32
#
#       Net Change  % Change    Market Cap        Country  IPO Year    Volume  \
# 4831       0.070    0.052%  4.504342e+09  United States    2016.0    421927
# 2533      -0.020   -0.639%  1.166904e+08  United States    1997.0    242498
# 6431       0.060    0.338%           NaN  United States       NaN     92706
# 760       -0.009   -0.092%  9.621557e+08            NaN    2021.0    380174
# 3934       0.000     0.00%           NaN  United States       NaN       368
# 7497      -0.010   -0.124%  2.459526e+08  United States    2012.0    418011
# 2155      -0.660  -13.018%  9.543192e+08            NaN    2021.0   1465268
# 1673       0.350    3.646%  9.865166e+07         Israel       NaN     16928
# 2113       0.006    1.695%  0.000000e+00  United States    2021.0      2722
# 5323       0.050    0.797%  9.233654e+09  United States       NaN  49707384
#
#            Sector                                           Industry    weight
# 4831  Health Care  Biotechnology: Commercial Physical & Biologica...  0.000082
# 2533   Technology                                     Semiconductors  0.000002
# 6431          NaN                                                NaN       NaN
# 760           NaN                                                NaN  0.000017
# 3934          NaN                                                NaN       NaN
# 7497          NaN                                                NaN  0.000004
# 2155          NaN                                                NaN  0.000017
# 1673  Health Care                             Industrial Specialties  0.000002
# 2113   Technology            Computer Software: Prepackaged Software  0.000000
# 5323  Real Estate                      Real Estate Investment Trusts  0.000167

# %%
df = df[df['weight'].notna()]
df
# Out:
#      Symbol                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $125.13
# 1        AA                    Alcoa Corporation Common Stock     $60.57
# 2       AAC  Ares Acquisition Corporation Class A Ordinary ...     $9.79
# 3      AACG   ATA Creativity Global American Depositary Shares     $1.01
# 4      AACI            Armada Acquisition Corp. I Common Stock     $9.84
# ...     ...                                                ...       ...
# 8381    ZWS      Zurn Water Solutions Corporation Common Stock    $26.71
# 8382     ZY                         Zymergen Inc. Common Stock     $1.27
# 8383   ZYME                       Zymeworks Inc. Common Shares     $5.99
# 8384   ZYNE          Zynerba Pharmaceuticals Inc. Common Stock    $0.959
# 8385   ZYXI                            Zynex Inc. Common Stock     $7.25
#
#       Net Change % Change    Market Cap        Country  IPO Year   Volume  \
# 0         2.7300    2.23%  3.755319e+10  United States    1999.0  2594645
# 1        -1.4800  -2.385%  1.117206e+10            NaN    2016.0  8738351
# 2         0.0000    0.00%  1.223750e+09            NaN    2021.0    50979
# 3        -0.0200  -1.942%  3.191457e+07          China       NaN     7909
# 4         0.0000    0.00%  2.037815e+08  United States    2021.0        3
# ...          ...      ...           ...            ...       ...      ...
# 8381      0.0900   0.338%  3.364593e+09  United States    2012.0   653901
# 8382     -0.0500  -3.788%  1.309888e+08  United States    2021.0  1134269
# 8383      0.1700   2.921%  3.460495e+08         Canada    2017.0  1922692
# 8384     -0.0293  -2.965%  4.183297e+07  United States    2015.0   290568
# 8385      0.0000    0.00%  2.830842e+08  United States       NaN   306119
#
#                       Sector                                    Industry  \
# 0                Industrials                         Electrical Products
# 1                Industrials                          Metal Fabrications
# 2                    Finance                           Business Services
# 3     Consumer Discretionary              Service to the Health Industry
# 4                Industrials             Consumer Electronics/Appliances
# ...                      ...                                         ...
# 8381               Utilities                      Environmental Services
# 8382             Industrials                      Industrial Specialties
# 8383                     NaN                                         NaN
# 8384             Health Care  Biotechnology: Pharmaceutical Preparations
# 8385             Health Care                       Other Pharmaceuticals
#
#             weight
# 0     6.809173e-04
# 1     2.025726e-04
# 2     2.218913e-05
# 3     5.786775e-07
# 4     3.694981e-06
# ...            ...
# 8381  6.100706e-05
# 8382  2.375098e-06
# 8383  6.274596e-06
# 8384  7.585187e-07
# 8385  5.132905e-06
#
# [7926 rows x 12 columns]

# %%
df = df.sort_values(by='weight', ascending=False).reset_index()
# Out:
#    level_0  index Symbol                                             Name  \
# 0        0     21   AAPL                          Apple Inc. Common Stock
# 1        1   5071   MSFT               Microsoft Corporation Common Stock
# 2        2   3413   GOOG              Alphabet Inc. Class C Capital Stock
# 3        3   3414  GOOGL               Alphabet Inc. Class A Common Stock
# 4        4    465   AMZN                     Amazon.com Inc. Common Stock
# 5        5   7622   TSLA                          Tesla Inc. Common Stock
# 6        6   2790     FB         Meta Platforms Inc. Class A Common Stock
# 7        7   2386   DXCM                         DexCom Inc. Common Stock
# 8        8   7624    TSM  Taiwan Semiconductor Manufacturing Company Ltd.
# 9        9   4205    JNJ                   Johnson & Johnson Common Stock
#
#   Last Sale  Net Change % Change    Market Cap        Country  IPO Year  \
# 0   $137.59        0.24   0.175%  2.385445e+12  United States    1980.0
# 1   $252.56       -0.58  -0.229%  1.888905e+12  United States    1986.0
# 2  $2186.26      -28.65  -1.294%  1.439652e+12  United States    2004.0
# 3  $2178.16      -29.52  -1.337%  1.434318e+12  United States       NaN
# 4  $2151.82        5.44   0.253%  1.094675e+12  United States    1997.0
# 5   $663.90      -45.52  -6.417%  6.878070e+11  United States    2010.0
# 6   $193.54        2.25   1.176%  5.237818e+11  United States    2012.0
# 7   $321.23        5.11   1.616%  5.043359e+11  United States    2005.0
# 8    $90.78        0.57   0.632%  4.707920e+11         Taiwan    1997.0
# 9   $176.98        3.04   1.748%  4.657055e+11  United States       NaN
#
#       Volume                  Sector  \
# 0  137190936              Technology
# 1   39169251              Technology
# 2    1878093              Technology
# 3    2445055              Technology
# 4    4967953  Consumer Discretionary
# 5   48187084  Consumer Discretionary
# 6   31437575              Technology
# 7     824295             Health Care
# 8   10458366              Technology
# 9    7521142             Health Care
#
#                                      Industry    weight
# 0                      Computer Manufacturing  0.043253
# 1     Computer Software: Prepackaged Software  0.034250
# 2           Internet and Information Services  0.026104
# 3           Internet and Information Services  0.026007
# 4              Catalog/Specialty Distribution  0.019849
# 5                          Auto Manufacturing  0.012471
# 6           Internet and Information Services  0.009497
# 7                        Medical Specialities  0.009145
# 8                              Semiconductors  0.008536
# 9  Biotechnology: Pharmaceutical Preparations  0.008444

# %%
top20_weight = df.head(20)['weight'].sum()
top20_weight
# Out:
# 0.2636150071237483

# %%
from get_data import get_candles_by_ticker
from datetime import datetime
from time import sleep

# %%
def candles_to_csv(ticker, from_date, to_date):
    prices = get_candles_by_ticker(ticker, from_date, to_date)

    df = pd.DataFrame(prices, columns=['open', 'close', 'low', 'high', 'volume'])
    df.to_csv('candles/%s_candles.csv' % ticker)

# %%
date_from = datetime(2020, 5, 1)
date_to = datetime(2020, 11, 1)

for i in range(20):
    candles_to_csv(df.iloc[i]['Symbol'], date_from, date_to)
    sleep(4)

# %%
top20_close = []

for i in range(20):
    filename = 'candles/%s_candles.csv' % df.iloc[i]['Symbol']
    candles_df = pd.read_csv(filename)
    top20_close.append(candles_df['close'].to_numpy() * df.iloc[i]['weight'] / top20_weight)

# %%
import numpy as np

for i, e in enumerate(top20_close):
        top20_close[i] = top20_close[i].tolist()

# %%
for e in top20_close:
    while len(e) < 2000:
        e.append(0)
    while len(e) > 2000:
        e.pop()

# %%
for i, e in enumerate(top20_close):
    top20_close[i] = np.array(top20_close[i])

top20_close_avg = sum(top20_close)
top20_close_avg
# Out:
# array([546.80090586, 546.04871725, 539.31658686, ..., 671.89241213,
#        673.35365102, 671.68566513])

# %%
import matplotlib.pyplot as plt

plt.plot(top20_close_avg)

# %%
corr_dict = {}
corr_dict['total'] = top20_close_avg
for i in range(5):
    corr_dict[df.iloc[i]['Symbol']] =  np.array(top20_close[i]) / top20_weight

corr_df = pd.DataFrame(corr_dict)

corr_df.corr()
# Out:
#           total      AAPL      MSFT      GOOG     GOOGL      AMZN
# total  1.000000  0.935399  0.958969  0.930965  0.929067  0.982416
# AAPL   0.935399  1.000000  0.905776  0.817689  0.811790  0.941820
# MSFT   0.958969  0.905776  1.000000  0.870017  0.870889  0.968610
# GOOG   0.930965  0.817689  0.870017  1.000000  0.992440  0.868643
# GOOGL  0.929067  0.811790  0.870889  0.992440  1.000000  0.866794
# AMZN   0.982416  0.941820  0.968610  0.868643  0.866794  1.000000

# %%
import pandas as pd
from datetime import datetime, timedelta
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
from matplotlib import pyplot as plt
from typing import List

# %%
def make_dataset(
    df,
     window_size,
     batch_size,
     shuffle=True
     ):
  features = df[["close"]].iloc[:-window_size]
  data = np.array(features, dtype=np.float32)
  ds = tf.keras.preprocessing.timeseries_dataset_from_array(
      data=data,
      targets=df["close"].iloc[window_size:],
      sequence_length=window_size,
      sequence_stride=1,
      shuffle=shuffle,
      batch_size=batch_size)
  return ds

# %%
window_size = 10
batch_size = 8
train_ds = make_dataset(df=train_df, window_size=window_size, batch_size=batch_size, use_scaler=True, shuffle=True)
val_ds = make_dataset(df=test_df, window_size=window_size, batch_size=batch_size, use_scaler=True, shuffle=True)

# %%
train_val_ratio = 5 / 6

# %%
def compile_and_fit(model, train_ds, val_ds, num_epochs: int = 10):
  model.compile(
        loss=tf.losses.MeanSquaredError(),
        optimizer=tf.optimizers.Adam(),
        metrics=[tf.metrics.MeanAbsoluteError()]
      )
  history = model.fit(
      train_ds,
      epochs=num_epochs,
      validation_data=val_ds,
      verbose=0
      )
  return history

# %%
lstm_model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(32, return_sequences=False),
    tf.keras.layers.Dense(1)
])

# %%
histories = []

# %%
for i in range(20):
    ticker = df.iloc[i]['Symbol']
    candles_df = pd.read_csv('candles/%s_candles.csv' % ticker)

    train_size = int(len(candles_df) * train_val_ratio)
    train_df = candles_df.iloc[:train_size]
    test_df = candles_df.iloc[train_size:]

    window_size = 10
    batch_size = 8
    train_ds = make_dataset(df=train_df, window_size=window_size, batch_size=batch_size, shuffle=True)
    val_ds = make_dataset(df=test_df, window_size=window_size, batch_size=batch_size, shuffle=True)

    history = compile_and_fit(lstm_model, train_ds, val_ds, num_epochs=25)
    histories.append(history)
    print('%d / 20' % i)
# Out:
# 0 / 20
# 1 / 20
# 2 / 20
# 3 / 20
# 4 / 20
# 5 / 20
# 6 / 20
# 7 / 20
# 8 / 20
# 9 / 20
# 10 / 20
# 11 / 20
# 12 / 20
# 13 / 20
# 14 / 20
# 15 / 20
# 16 / 20
# 17 / 20
# 18 / 20
# 19 / 20

# %%
plt.plot(histories[10].history["val_loss"])
plt.plot(histories[10].history["loss"])

# %%
predictions = []
portfolio = 0
profit = 0

for i in range(20):
    ticker = df.iloc[i]['Symbol']
    candles_df = pd.read_csv('candles/%s_candles.csv' % ticker)

    train_size = int(len(candles_df) * train_val_ratio)
    train_df = candles_df.iloc[:train_size]
    val_df = candles_df.iloc[train_size:(train_size - candles_df.shape[0]) // 2]
    test_df = candles_df.iloc[(train_size - candles_df.shape[0]) // 2:]

    portfolio += test_df['close'].to_list()[0]

    if val_df['close'].to_list()[-1] < np.mean(lstm_model.predict(test_df)):
        predictions.append((ticker, 'buy'))
        profit += test_df['close'].to_list()[-1] - test_df['close'].to_list()[0]
    else:
        predictions.append((ticker, 'sell'))
        profit -= test_df['close'].to_list()[-1] - test_df['close'].to_list()[0]
# Out:
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 3ms/step

# %%
print(predictions, "\nprofit: %.2f" % profit)
# Out:
# [('AAPL', 'buy'), ('MSFT', 'buy'), ('GOOG', 'sell'), ('GOOGL', 'sell'), ('AMZN', 'sell'), ('TSLA', 'sell'), ('FB', 'buy'), ('DXCM', 'sell'), ('TSM', 'buy'), ('JNJ', 'buy'), ('UNH', 'sell'), ('NVDA', 'buy'), ('V', 'buy'), ('XOM', 'buy'), ('JPM', 'buy'), ('PG', 'buy'), ('CVX', 'buy'), ('WMT', 'buy'), ('MA', 'sell'), ('HD', 'sell')]
# profit: 366.17
